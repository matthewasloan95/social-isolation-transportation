# %%
import pandas as pd

# %%
#207 AARP Survey
df_2017 = pd.read_csv('Data/2017 AARP/aarp_2017.csv')
# Out:
# C:\Users\Tonyj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,142,143,144,145) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2017
# Out:
#       Unnamed: 0    case#                market                    community  \
# 0              0      1.0     Albany County, NY      Albany County, New York
# 1              1      2.0     Albany County, NY      Albany County, New York
# 2              2      3.0     Albany County, NY      Albany County, New York
# 3              3      4.0     Albany County, NY      Albany County, New York
# 4              4      6.0     Albany County, NY      Albany County, New York
# ...          ...      ...                   ...                          ...
# 6665        6665  11690.0  Milwaukee County, WI  Milwaukee County, Wisconsin
# 6666        6666  11736.0  Milwaukee County, WI  Milwaukee County, Wisconsin
# 6667        6667  11743.0  Milwaukee County, WI  Milwaukee County, Wisconsin
# 6668        6668  11772.0  Milwaukee County, WI  Milwaukee County, Wisconsin
# 6669        6669  11773.0  Milwaukee County, WI  Milwaukee County, Wisconsin
#
#      e_lans     age_samp phone_type  \
# ...
